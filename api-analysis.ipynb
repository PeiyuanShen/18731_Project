# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib.dates as mdates
import datetime
from collections import defaultdict, OrderedDict
import random
import re
import json
from datetime import datetime, timedelta
import arrow

import sys, os

# %% [markdown]
# # Lancie

# %%
data_path = os.path.join('lancie', 'CallGraphEdge.csv')

# %%
df = pd.read_csv(data_path, sep='\t', header=None).loc[:, [1, 3]]
df.columns = ['caller', 'callee']
df
# Out:
#                                                   caller  \
# 0      <java.io.File: java.lang.String[] list()>/java...
# 1      <sun.util.calendar.ZoneInfoFile: void <clinit>...
# 2      <sun.util.calendar.ZoneInfoFile: void <clinit>...
# 3      <java.lang.invoke.InnerClassLambdaMetafactory:...
# 4      <sun.security.util.AbstractAlgorithmConstraint...
# ...                                                  ...
# 57920  <ch.wisv.areafiftylan.products.controller.Orde...
# 57921  <ch.wisv.areafiftylan.products.controller.Tick...
# 57922  <ch.wisv.areafiftylan.products.controller.Orde...
# 57923  <ch.wisv.areafiftylan.products.controller.Orde...
# 57924  <ch.wisv.areafiftylan.products.controller.Orde...
#
#                                                   callee
# 0      <java.io.UnixFileSystem: java.lang.String[] li...
# 1      <java.security.AccessController: java.lang.Obj...
# 2      <java.security.AccessController: java.lang.Obj...
# 3      <java.security.AccessController: java.lang.Obj...
# 4      <java.security.AccessController: java.lang.Obj...
# ...                                                  ...
# 57920  <org.springframework.web.servlet.support.Servl...
# 57921  <net.logstash.logback.marker.Markers: net.logs...
# 57922  <net.logstash.logback.marker.Markers: net.logs...
# 57923  <net.logstash.logback.marker.Markers: net.logs...
# 57924  <net.logstash.logback.argument.StructuredArgum...
#
# [57925 rows x 2 columns]

# %% [markdown]
# ## Caller & Callee
#
# 1. If a callee has "Team", then its caller definately have "team"

# %%
df_both = df[(df.caller.str.contains("Team") & df.callee.str.contains("Team"))]
df_both
# Out:
#                                                   caller  \
# 3953   <ch.wisv.areafiftylan.teams.service.TeamServic...
# 3954   <ch.wisv.areafiftylan.teams.controller.TeamRes...
# 4192   <ch.wisv.areafiftylan.utils.ExportController: ...
# 4307   <ch.wisv.areafiftylan.teams.service.TeamServic...
# 4530   <ch.wisv.areafiftylan.teams.controller.TeamRes...
# ...                                                  ...
# 46315  <ch.wisv.areafiftylan.utils.ExportController: ...
# 46316  <ch.wisv.areafiftylan.teams.controller.TeamRes...
# 57613  <ch.wisv.areafiftylan.teams.model.Team: boolea...
# 57614  <ch.wisv.areafiftylan.teams.model.Team: int ha...
# 57615  <ch.wisv.areafiftylan.teams.model.Team: java.l...
#
#                                                   callee
# 3953   <ch.wisv.areafiftylan.teams.service.TeamServic...
# 3954   <ch.wisv.areafiftylan.teams.service.TeamServic...
# 4192   <ch.wisv.areafiftylan.teams.model.TeamExportDT...
# 4307   <ch.wisv.areafiftylan.teams.model.TeamInviteRe...
# 4530   <ch.wisv.areafiftylan.teams.model.TeamDTO: jav...
# ...                                                  ...
# 46315  <ch.wisv.areafiftylan.teams.service.TeamServic...
# 46316  <ch.wisv.areafiftylan.teams.service.TeamServic...
# 57613  <ch.wisv.areafiftylan.teams.model.Team: int ge...
# 57614  <ch.wisv.areafiftylan.teams.model.Team: int ge...
# 57615  <ch.wisv.areafiftylan.teams.model.Team: int ge...
#
# [67 rows x 2 columns]

# %% [markdown]
# ## Call tree

# %%
parent2children = defaultdict(list) # caller:[a list of callees]
child2parents = defaultdict(list) # callee:[a list of callers]
n = len(df_both)

for i in range(n):
    caller, callee = df_both.iloc[i, :]
    caller = caller.split('/')[0][1:-1]
    callee = callee[1:-1]
    parent2children[caller].append(callee)
    child2parents[callee].append(caller)

def printTree(dic):
    for key, val in dic.items():
        print(key)
        print(val)
        print("*****************************************************************************")

print(len(parent2children))
printTree(parent2children)
# Out:
# 35
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: boolean removeMember(java.lang.Long,java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team delete(java.lang.Long)', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity removeTeamMember(java.lang.Long,java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: boolean removeMember(java.lang.Long,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.utils.ExportController: ch.wisv.areafiftylan.teams.model.TeamExportDTO lambda$exportUsers$2(ch.wisv.areafiftylan.teams.model.Team)
# ['ch.wisv.areafiftylan.teams.model.TeamExportDTO: void <init>(java.lang.Long,java.lang.String,java.lang.Long,java.util.List)', 'ch.wisv.areafiftylan.teams.model.Team: java.lang.Long getId()', 'ch.wisv.areafiftylan.teams.model.Team: java.lang.String getTeamName()', 'ch.wisv.areafiftylan.teams.model.Team: java.util.Set getMembers()', 'ch.wisv.areafiftylan.teams.model.Team: ch.wisv.areafiftylan.users.model.User getCaptain()']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.TeamInviteResponse lambda$teamInviteTokensToReponses$4(ch.wisv.areafiftylan.security.token.TeamInviteToken)
# ['ch.wisv.areafiftylan.teams.model.TeamInviteResponse: void <init>(java.lang.Long,java.lang.String,java.lang.String,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity add(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.TeamDTO)
# ['ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getTeamName()', 'ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getTeamName()', 'ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getTeamName()', 'ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getTeamName()', 'ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getCaptainEmail()', 'ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getCaptainEmail()', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team create(java.lang.String,java.lang.String)', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team create(java.lang.String,java.lang.String)', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: boolean teamnameUsed(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: ch.wisv.areafiftylan.teams.model.Team update(java.lang.Long,ch.wisv.areafiftylan.teams.model.TeamDTO)
# ['ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getTeamName()', 'ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getCaptainEmail()', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team update(java.lang.Long,java.lang.String,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.Team: boolean equals(java.lang.Object)
# ['ch.wisv.areafiftylan.teams.model.Team: java.lang.Long getId()', 'ch.wisv.areafiftylan.teams.model.Team: java.lang.String getTeamName()', 'ch.wisv.areafiftylan.teams.model.Team: java.util.Set getMembers()', 'ch.wisv.areafiftylan.teams.model.Team: ch.wisv.areafiftylan.users.model.User getCaptain()', 'ch.wisv.areafiftylan.teams.model.Team: int getSize()']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.Team: int hashCode()
# ['ch.wisv.areafiftylan.teams.model.Team: java.lang.Long getId()', 'ch.wisv.areafiftylan.teams.model.Team: java.lang.String getTeamName()', 'ch.wisv.areafiftylan.teams.model.Team: java.util.Set getMembers()', 'ch.wisv.areafiftylan.teams.model.Team: ch.wisv.areafiftylan.users.model.User getCaptain()', 'ch.wisv.areafiftylan.teams.model.Team: int getSize()']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.Team: java.lang.String toString()
# ['ch.wisv.areafiftylan.teams.model.Team: java.lang.Long getId()', 'ch.wisv.areafiftylan.teams.model.Team: java.lang.String getTeamName()', 'ch.wisv.areafiftylan.teams.model.Team: java.util.Set getMembers()', 'ch.wisv.areafiftylan.teams.model.Team: ch.wisv.areafiftylan.users.model.User getCaptain()', 'ch.wisv.areafiftylan.teams.model.Team: int getSize()']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.security.token.TeamInviteToken inviteMember(java.lang.Long,java.lang.String)
# ['ch.wisv.areafiftylan.security.token.TeamInviteToken: void <init>(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.Team)', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: boolean isUserAlreadyInvited(java.lang.String,ch.wisv.areafiftylan.teams.model.Team)', 'ch.wisv.areafiftylan.utils.mail.MailServiceImpl: void sendTeamInviteMail(ch.wisv.areafiftylan.users.model.User,java.lang.String,ch.wisv.areafiftylan.users.model.User)']
# *****************************************************************************
# ch.wisv.areafiftylan.utils.mail.MailRestController: org.springframework.http.ResponseEntity sendMailToTeam(java.lang.Long,ch.wisv.areafiftylan.utils.mail.MailDTO)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)', 'ch.wisv.areafiftylan.utils.mail.MailServiceImpl: void sendTemplateMailToTeam(ch.wisv.areafiftylan.teams.model.Team,ch.wisv.areafiftylan.utils.mail.MailDTO)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team update(java.lang.Long,java.lang.String,java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity changeCaptain(ch.wisv.areafiftylan.users.model.User,java.lang.Long,java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team update(java.lang.Long,java.lang.String,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Set getTeamMembersById(java.lang.Long)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Set getTeamMembersByIdAdmin(java.lang.Long)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.seats.service.SeatServiceImpl: java.util.List getSeatsByTeamName(java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamByTeamname(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.products.service.TicketServiceImpl: java.util.Collection getOwnedTicketsAndFromTeamMembers(ch.wisv.areafiftylan.users.model.User)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.Collection getTeamByCaptainId(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.users.controller.CurrentUserRestController: java.util.Collection getCurrentTeams(ch.wisv.areafiftylan.users.model.User)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.Collection getTeamsByMemberEmail(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity inviteTeamMember(java.lang.Long,java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.security.token.TeamInviteToken inviteMember(java.lang.Long,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity revokeTeamInvite(java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: void revokeInvite(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.users.controller.CurrentUserRestController: java.util.List getOpenInvites(ch.wisv.areafiftylan.users.model.User)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List findTeamInvitesByEmail(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.List getTeamInvitesByTeam(java.lang.Long)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List findTeamInvitesByTeamId(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List findTeamInvitesByEmail(java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List teamInviteTokensToReponses(java.util.Collection)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List findTeamInvitesByTeamId(java.lang.Long)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List teamInviteTokensToReponses(java.util.Collection)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity acceptTeamInvite(java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: void addMemberByInvite(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: void addMemberByInvite(java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: void addMember(java.lang.Long,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity addTeamMember(java.lang.Long,java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: void addMember(java.lang.Long,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.exception.TeamNotFoundException lambda$getTeamByTeamname$1(java.lang.String)
# ['ch.wisv.areafiftylan.exception.TeamNotFoundException: void <init>(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.exception.TeamNotFoundException lambda$getTeamById$0(java.lang.Long)
# ['ch.wisv.areafiftylan.exception.TeamNotFoundException: void <init>(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.products.controller.TicketRestController: java.util.Collection getTicketsFromTeamMembers(ch.wisv.areafiftylan.users.model.User)
# ['ch.wisv.areafiftylan.products.service.TicketServiceImpl: java.util.Collection getOwnedTicketsAndFromTeamMembers(ch.wisv.areafiftylan.users.model.User)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Collection getSeatsForTeam(java.lang.String)
# ['ch.wisv.areafiftylan.seats.service.SeatServiceImpl: java.util.List getSeatsByTeamName(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team create(java.lang.String,java.lang.String)
# ['ch.wisv.areafiftylan.teams.model.Team: void <init>(java.lang.String,ch.wisv.areafiftylan.users.model.User)']
# *****************************************************************************
# ch.wisv.areafiftylan.utils.ExportController: java.util.Map exportUsers()
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.Collection getAllTeams()']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Collection readTeams()
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.Collection getAllTeams()']
# *****************************************************************************

# %%
print(len(child2parents))
printTree(child2parents)
# Out:
# 35
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team delete(java.lang.Long)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: boolean removeMember(java.lang.Long,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: boolean removeMember(java.lang.Long,java.lang.String)
# ['ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity removeTeamMember(java.lang.Long,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.TeamExportDTO: void <init>(java.lang.Long,java.lang.String,java.lang.Long,java.util.List)
# ['ch.wisv.areafiftylan.utils.ExportController: ch.wisv.areafiftylan.teams.model.TeamExportDTO lambda$exportUsers$2(ch.wisv.areafiftylan.teams.model.Team)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.TeamInviteResponse: void <init>(java.lang.Long,java.lang.String,java.lang.String,java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.TeamInviteResponse lambda$teamInviteTokensToReponses$4(ch.wisv.areafiftylan.security.token.TeamInviteToken)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getTeamName()
# ['ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity add(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.TeamDTO)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity add(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.TeamDTO)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity add(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.TeamDTO)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity add(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.TeamDTO)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: ch.wisv.areafiftylan.teams.model.Team update(java.lang.Long,ch.wisv.areafiftylan.teams.model.TeamDTO)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getCaptainEmail()
# ['ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity add(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.TeamDTO)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity add(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.TeamDTO)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: ch.wisv.areafiftylan.teams.model.Team update(java.lang.Long,ch.wisv.areafiftylan.teams.model.TeamDTO)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.Team: java.lang.Long getId()
# ['ch.wisv.areafiftylan.utils.ExportController: ch.wisv.areafiftylan.teams.model.TeamExportDTO lambda$exportUsers$2(ch.wisv.areafiftylan.teams.model.Team)', 'ch.wisv.areafiftylan.teams.model.Team: boolean equals(java.lang.Object)', 'ch.wisv.areafiftylan.teams.model.Team: int hashCode()', 'ch.wisv.areafiftylan.teams.model.Team: java.lang.String toString()']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.Team: java.lang.String getTeamName()
# ['ch.wisv.areafiftylan.utils.ExportController: ch.wisv.areafiftylan.teams.model.TeamExportDTO lambda$exportUsers$2(ch.wisv.areafiftylan.teams.model.Team)', 'ch.wisv.areafiftylan.teams.model.Team: boolean equals(java.lang.Object)', 'ch.wisv.areafiftylan.teams.model.Team: int hashCode()', 'ch.wisv.areafiftylan.teams.model.Team: java.lang.String toString()']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.Team: java.util.Set getMembers()
# ['ch.wisv.areafiftylan.utils.ExportController: ch.wisv.areafiftylan.teams.model.TeamExportDTO lambda$exportUsers$2(ch.wisv.areafiftylan.teams.model.Team)', 'ch.wisv.areafiftylan.teams.model.Team: boolean equals(java.lang.Object)', 'ch.wisv.areafiftylan.teams.model.Team: int hashCode()', 'ch.wisv.areafiftylan.teams.model.Team: java.lang.String toString()']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.Team: ch.wisv.areafiftylan.users.model.User getCaptain()
# ['ch.wisv.areafiftylan.utils.ExportController: ch.wisv.areafiftylan.teams.model.TeamExportDTO lambda$exportUsers$2(ch.wisv.areafiftylan.teams.model.Team)', 'ch.wisv.areafiftylan.teams.model.Team: boolean equals(java.lang.Object)', 'ch.wisv.areafiftylan.teams.model.Team: int hashCode()', 'ch.wisv.areafiftylan.teams.model.Team: java.lang.String toString()']
# *****************************************************************************
# ch.wisv.areafiftylan.security.token.TeamInviteToken: void <init>(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.Team)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.security.token.TeamInviteToken inviteMember(java.lang.Long,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team create(java.lang.String,java.lang.String)
# ['ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity add(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.TeamDTO)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity add(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.TeamDTO)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)
# ['ch.wisv.areafiftylan.utils.mail.MailRestController: org.springframework.http.ResponseEntity sendMailToTeam(java.lang.Long,ch.wisv.areafiftylan.utils.mail.MailDTO)', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team update(java.lang.Long,java.lang.String,java.lang.String)', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.security.token.TeamInviteToken inviteMember(java.lang.Long,java.lang.String)', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: boolean removeMember(java.lang.Long,java.lang.String)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity changeCaptain(ch.wisv.areafiftylan.users.model.User,java.lang.Long,java.lang.String)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Set getTeamMembersById(java.lang.Long)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Set getTeamMembersByIdAdmin(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamByTeamname(java.lang.String)
# ['ch.wisv.areafiftylan.seats.service.SeatServiceImpl: java.util.List getSeatsByTeamName(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: boolean teamnameUsed(java.lang.String)
# ['ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity add(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.TeamDTO)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.Collection getTeamByCaptainId(java.lang.Long)
# ['ch.wisv.areafiftylan.products.service.TicketServiceImpl: java.util.Collection getOwnedTicketsAndFromTeamMembers(ch.wisv.areafiftylan.users.model.User)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.Collection getTeamsByMemberEmail(java.lang.String)
# ['ch.wisv.areafiftylan.users.controller.CurrentUserRestController: java.util.Collection getCurrentTeams(ch.wisv.areafiftylan.users.model.User)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team update(java.lang.Long,java.lang.String,java.lang.String)
# ['ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity changeCaptain(ch.wisv.areafiftylan.users.model.User,java.lang.Long,java.lang.String)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: ch.wisv.areafiftylan.teams.model.Team update(java.lang.Long,ch.wisv.areafiftylan.teams.model.TeamDTO)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.security.token.TeamInviteToken inviteMember(java.lang.Long,java.lang.String)
# ['ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity inviteTeamMember(java.lang.Long,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: boolean isUserAlreadyInvited(java.lang.String,ch.wisv.areafiftylan.teams.model.Team)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.security.token.TeamInviteToken inviteMember(java.lang.Long,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: void revokeInvite(java.lang.String)
# ['ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity revokeTeamInvite(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List findTeamInvitesByEmail(java.lang.String)
# ['ch.wisv.areafiftylan.users.controller.CurrentUserRestController: java.util.List getOpenInvites(ch.wisv.areafiftylan.users.model.User)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List findTeamInvitesByTeamId(java.lang.Long)
# ['ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.List getTeamInvitesByTeam(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List teamInviteTokensToReponses(java.util.Collection)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List findTeamInvitesByEmail(java.lang.String)', 'ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List findTeamInvitesByTeamId(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: void addMemberByInvite(java.lang.String)
# ['ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity acceptTeamInvite(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: void addMember(java.lang.Long,java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: void addMemberByInvite(java.lang.String)', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity addTeamMember(java.lang.Long,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.exception.TeamNotFoundException: void <init>(java.lang.String)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.exception.TeamNotFoundException lambda$getTeamByTeamname$1(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.exception.TeamNotFoundException: void <init>(java.lang.Long)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.exception.TeamNotFoundException lambda$getTeamById$0(java.lang.Long)']
# *****************************************************************************
# ch.wisv.areafiftylan.utils.mail.MailServiceImpl: void sendTemplateMailToTeam(ch.wisv.areafiftylan.teams.model.Team,ch.wisv.areafiftylan.utils.mail.MailDTO)
# ['ch.wisv.areafiftylan.utils.mail.MailRestController: org.springframework.http.ResponseEntity sendMailToTeam(java.lang.Long,ch.wisv.areafiftylan.utils.mail.MailDTO)']
# *****************************************************************************
# ch.wisv.areafiftylan.utils.mail.MailServiceImpl: void sendTeamInviteMail(ch.wisv.areafiftylan.users.model.User,java.lang.String,ch.wisv.areafiftylan.users.model.User)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.security.token.TeamInviteToken inviteMember(java.lang.Long,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.products.service.TicketServiceImpl: java.util.Collection getOwnedTicketsAndFromTeamMembers(ch.wisv.areafiftylan.users.model.User)
# ['ch.wisv.areafiftylan.products.controller.TicketRestController: java.util.Collection getTicketsFromTeamMembers(ch.wisv.areafiftylan.users.model.User)']
# *****************************************************************************
# ch.wisv.areafiftylan.seats.service.SeatServiceImpl: java.util.List getSeatsByTeamName(java.lang.String)
# ['ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Collection getSeatsForTeam(java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.Team: void <init>(java.lang.String,ch.wisv.areafiftylan.users.model.User)
# ['ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team create(java.lang.String,java.lang.String)']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.Collection getAllTeams()
# ['ch.wisv.areafiftylan.utils.ExportController: java.util.Map exportUsers()', 'ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Collection readTeams()']
# *****************************************************************************
# ch.wisv.areafiftylan.teams.model.Team: int getSize()
# ['ch.wisv.areafiftylan.teams.model.Team: boolean equals(java.lang.Object)', 'ch.wisv.areafiftylan.teams.model.Team: int hashCode()', 'ch.wisv.areafiftylan.teams.model.Team: java.lang.String toString()']
# *****************************************************************************

# %%
def findRootsOrLeaves(graph_dic):
    res = set()
    statusMap = defaultdict(int)
    
    def dfs(node):
        if statusMap[node] != 0:
            if statusMap[node] == 1:
                print("recursive on %s!" % node )
            return
        
        statusMap[node] = 1
        if node not in graph_dic:
            res.add(node)
        else:
            for adjacent in graph_dic[node]:
                dfs(adjacent)
        statusMap[node] = 2
        
    for node in list(graph_dic.keys()):
        dfs(node)
    return res

roots = findRootsOrLeaves(child2parents)
leaves = findRootsOrLeaves(parent2children)
print("Root number: %d" % len(roots))
for root in roots:
    print(root)

print("\n**************************************************")
print("Leaves number: %d" % len(leaves))
for leaf in leaves:
    print(leaf)

roots & leaves # Empty - roots and leaves not intersect.
# Out:
# Root number: 26
# ch.wisv.areafiftylan.users.controller.CurrentUserRestController: java.util.List getOpenInvites(ch.wisv.areafiftylan.users.model.User)
# ch.wisv.areafiftylan.utils.mail.MailRestController: org.springframework.http.ResponseEntity sendMailToTeam(java.lang.Long,ch.wisv.areafiftylan.utils.mail.MailDTO)
# ch.wisv.areafiftylan.utils.ExportController: ch.wisv.areafiftylan.teams.model.TeamExportDTO lambda$exportUsers$2(ch.wisv.areafiftylan.teams.model.Team)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity add(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.TeamDTO)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity inviteTeamMember(java.lang.Long,java.lang.String)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity acceptTeamInvite(java.lang.String)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)
# ch.wisv.areafiftylan.teams.model.Team: boolean equals(java.lang.Object)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity addTeamMember(java.lang.Long,java.lang.String)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.List getTeamInvitesByTeam(java.lang.Long)
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.exception.TeamNotFoundException lambda$getTeamByTeamname$1(java.lang.String)
# ch.wisv.areafiftylan.products.controller.TicketRestController: java.util.Collection getTicketsFromTeamMembers(ch.wisv.areafiftylan.users.model.User)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Set getTeamMembersById(java.lang.Long)
# ch.wisv.areafiftylan.teams.model.Team: int hashCode()
# ch.wisv.areafiftylan.users.controller.CurrentUserRestController: java.util.Collection getCurrentTeams(ch.wisv.areafiftylan.users.model.User)
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.TeamInviteResponse lambda$teamInviteTokensToReponses$4(ch.wisv.areafiftylan.security.token.TeamInviteToken)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity changeCaptain(ch.wisv.areafiftylan.users.model.User,java.lang.Long,java.lang.String)
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.exception.TeamNotFoundException lambda$getTeamById$0(java.lang.Long)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Set getTeamMembersByIdAdmin(java.lang.Long)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Collection getSeatsForTeam(java.lang.String)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: ch.wisv.areafiftylan.teams.model.Team update(java.lang.Long,ch.wisv.areafiftylan.teams.model.TeamDTO)
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity revokeTeamInvite(java.lang.String)
# ch.wisv.areafiftylan.utils.ExportController: java.util.Map exportUsers()
# ch.wisv.areafiftylan.teams.model.Team: java.lang.String toString()
# ch.wisv.areafiftylan.teams.controller.TeamRestController: java.util.Collection readTeams()
# ch.wisv.areafiftylan.teams.controller.TeamRestController: org.springframework.http.ResponseEntity removeTeamMember(java.lang.Long,java.lang.String)
#
# **************************************************
# Leaves number: 26
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: void revokeInvite(java.lang.String)
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: boolean teamnameUsed(java.lang.String)
# ch.wisv.areafiftylan.utils.mail.MailServiceImpl: void sendTeamInviteMail(ch.wisv.areafiftylan.users.model.User,java.lang.String,ch.wisv.areafiftylan.users.model.User)
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.Collection getAllTeams()
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: void addMember(java.lang.Long,java.lang.String)
# ch.wisv.areafiftylan.teams.model.Team: int getSize()
# ch.wisv.areafiftylan.utils.mail.MailServiceImpl: void sendTemplateMailToTeam(ch.wisv.areafiftylan.teams.model.Team,ch.wisv.areafiftylan.utils.mail.MailDTO)
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamByTeamname(java.lang.String)
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.Collection getTeamByCaptainId(java.lang.Long)
# ch.wisv.areafiftylan.teams.model.Team: ch.wisv.areafiftylan.users.model.User getCaptain()
# ch.wisv.areafiftylan.teams.model.Team: java.util.Set getMembers()
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team delete(java.lang.Long)
# ch.wisv.areafiftylan.teams.model.Team: java.lang.Long getId()
# ch.wisv.areafiftylan.exception.TeamNotFoundException: void <init>(java.lang.String)
# ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getTeamName()
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.List teamInviteTokensToReponses(java.util.Collection)
# ch.wisv.areafiftylan.teams.model.TeamExportDTO: void <init>(java.lang.Long,java.lang.String,java.lang.Long,java.util.List)
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: java.util.Collection getTeamsByMemberEmail(java.lang.String)
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: boolean isUserAlreadyInvited(java.lang.String,ch.wisv.areafiftylan.teams.model.Team)
# ch.wisv.areafiftylan.teams.service.TeamServiceImpl: ch.wisv.areafiftylan.teams.model.Team getTeamById(java.lang.Long)
# ch.wisv.areafiftylan.exception.TeamNotFoundException: void <init>(java.lang.Long)
# ch.wisv.areafiftylan.teams.model.Team: void <init>(java.lang.String,ch.wisv.areafiftylan.users.model.User)
# ch.wisv.areafiftylan.teams.model.TeamInviteResponse: void <init>(java.lang.Long,java.lang.String,java.lang.String,java.lang.String)
# ch.wisv.areafiftylan.teams.model.Team: java.lang.String getTeamName()
# ch.wisv.areafiftylan.teams.model.TeamDTO: java.lang.String getCaptainEmail()
# ch.wisv.areafiftylan.security.token.TeamInviteToken: void <init>(ch.wisv.areafiftylan.users.model.User,ch.wisv.areafiftylan.teams.model.Team)
# set()

# %% [markdown]
# ### Notice
# 1. Figured out that the "caller" column includes the "callee"
# 2. One caller may call multiple callee
# 3. Security sensitive functions not included in call grah
#     1. TeamRepository.saveAndFlush(...)
#     2. Teamrepository.delete(...)
